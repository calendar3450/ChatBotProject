# %%
def test_gemini_stream():
    prompt = "사과가 뭐지?"
    
    # stream=True 옵션을 주면 답변을 조각(chunk) 단위로 가져옵니다.
    response = model.generate_content(prompt, stream=True)
    
    for chunk in response:
        # 각 조각의 텍스트만 추출해서 즉시 출력
        print(chunk.text, end="", flush=True)

if __name__ == "__main__":
    test_gemini_stream()
# Out:
# 사과는 가장 흔하고 사랑받는 **과일** 중 하나입니다.
#
# 주요 특징은 다음과 같아요:
#
# *   **모양과 색깔:** 보통 둥근 모양이며, 빨강, 초록, 노랑 등 다양한 색깔을 띱니다.
# *   **맛과 식감:** 맛은 달콤하거나 새콤달콤하며, 식감은 아삭하고 즙이 많습니다.
# *   **재배:** 사과나무에서 열리며 전 세계적으로 널리 재배됩니다.
# *   **영양:** 섬유질, 비타민 C 등이 풍부하여 건강에도 매우 좋습니다. "하루 한 개의 사과는 의사를 멀리한다"는 서양 속담도 있을 정도예요.
# *   **용도:** 주로 생으로 먹지만, 주스, 잼, 파이, 사과소스 등으로 만들어 먹기도 합니다.
#
# 일상생활에서 쉽게 접할 수 있는 대중적인 과일이죠!
# --- 분석 완료 ---
